# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ARPIT\Dropbox\My PC (ArpitMaheshwariPC)\Downloads\CarPrice_Assignment.csv")

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  boreratio  stroke  \
# 0  convertible        rwd          front       88.6  ...       3.47    2.68
# 1  convertible        rwd          front       88.6  ...       3.47    2.68
# 2    hatchback        rwd          front       94.5  ...       2.68    3.47
# 3        sedan        fwd          front       99.8  ...       3.19    3.40
# 4        sedan        4wd          front       99.4  ...       3.19    3.40
#
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
sns.barplot(x=df['carbody'],y=df['price'])
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# BUILDING MODEL

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lm = LinearRegression()

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'carbody ordinal', 'engine ordinal'],
#       dtype='object')

# %%
X = df[['car_ID', 'symboling', 'wheelbase',
       'carlength', 'carwidth', 'carheight', 'curbweight',
        'enginesize', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg','carbody ordinal','engine ordinal']]
y = df['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.40,random_state=101)

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -55316.74295976486

# %% [markdown]
# PREDICTIONS

# %%
pred = lm.predict(X_test)

# %%
plt.scatter(y_test,pred)

# %% [markdown]
# EVALUATING MODEL

# %%
from sklearn import metrics

# %% [markdown]
# MAE

# %%
metrics.mean_absolute_error(y_test,pred)
# Out:
# 2049.975156458629

# %% [markdown]
# RMSE

# %%
np.sqrt(metrics.mean_squared_error(y_test,pred))
# Out:
# 2936.7335950735264

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.8430601471436727

# %% [markdown]
# CATBOOST REGRESSION

# %%
from catboost import CatBoostRegressor

# %%
cb = CatBoostRegressor()

# %%
cb.fit(X_train,y_train)
# Out:
# Learning rate set to 0.027578
# 0:	learn: 8381.9758891	total: 14.5ms	remaining: 14.4s
# 1:	learn: 8285.5165308	total: 15ms	remaining: 7.49s
# 2:	learn: 8177.5771167	total: 15.8ms	remaining: 5.24s
# 3:	learn: 8069.2865689	total: 16.8ms	remaining: 4.18s
# 4:	learn: 7939.1511057	total: 17.7ms	remaining: 3.52s
# 5:	learn: 7832.9158585	total: 18.4ms	remaining: 3.04s
# 6:	learn: 7732.9298971	total: 18.9ms	remaining: 2.68s
# 7:	learn: 7624.3443588	total: 19.7ms	remaining: 2.44s
# 8:	learn: 7515.1900167	total: 20.3ms	remaining: 2.24s
# 9:	learn: 7410.4720205	total: 21.1ms	remaining: 2.09s
# 10:	learn: 7293.6322705	total: 22ms	remaining: 1.97s
# 11:	learn: 7195.0548977	total: 22.7ms	remaining: 1.87s
# 12:	learn: 7089.9546050	total: 23.4ms	remaining: 1.78s
# 13:	learn: 6985.7065475	total: 24.2ms	remaining: 1.7s
# 14:	learn: 6880.8044502	total: 24.9ms	remaining: 1.63s
# 15:	learn: 6793.8453000	total: 25.8ms	remaining: 1.59s
# 16:	learn: 6680.1501662	total: 26.5ms	remaining: 1.53s
# ...

# %% [markdown]
# PREDICTIONS

# %%
predictionss = cb.predict(X_test)

# %%
plt.scatter(y_test,predictionss)

# %% [markdown]
# EVALUATION OF MODEL

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictionss))
# Out:
# 2364.9702028229894

# %%
metrics.mean_absolute_error(y_test,predictionss)
# Out:
# 1599.6828863558862

# %%
metrics.r2_score(y_test,predictionss)
# Out:
# 0.8982216315222233
